-- %%
CREATE TABLE orders

(
    order_id INT, 
    order_date DATE,
    order_customer_id INT, 
    order_status STRING
);


INSERT INTO orders
VALUES
(1, '2022-01-01', 1, 'placed'),
(2, '2022-01-01', 2,'pending'),
(3, '2022-01-02', 3,'delivered'),
(4, '2022-01-03', 4,'canceled'),
(5, '2022-01-04', 5,'returned'),
(6, '2022-01-05', 6,'placed');


SELECT * FROM orders
