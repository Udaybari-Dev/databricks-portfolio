# %%
import dlt
from pyspark.sql.functions import *
from pyspark.sql.types import *

# -----------------------------------------------
# STEP 1: Clean incoming bronze data
# -----------------------------------------------
@dlt.table(
    name = "silver_customers_clean",
    comment = "Cleaned and validated customers data",
    table_properties = {"quality": "silver"}
)
@dlt.expect("valid_customer_id", "customer_id IS NOT NULL")
@dlt.expect_or_drop("valid_customer_name", "full_name IS NOT NULL")
@dlt.expect("valid_email", "email IS NOT NULL")
def silver_customers_clean():
    return (
        dlt.read_stream("customers_bronze")
        .select(
            "customer_id",
            "full_name",
            "email",
            "city",
            "subscription_plan",
            "account_status",
            "updated_at"
        )
    )


# -----------------------------------------------
# STEP 2: SCD Type 2 using apply_changes
# -----------------------------------------------
dlt.create_streaming_table(
    name = "customers",
    comment = "SCD Type 2 customers table with full history",
    table_properties = {"quality": "silver"}
)

dlt.apply_changes(
    target = "customers",
    source = "silver_customers_clean",
    keys = ["customer_id"],
    sequence_by = col("updated_at"),
    stored_as_scd_type = 2,
    track_history_column_list = ["city", "subscription_plan", "account_status"]
)
