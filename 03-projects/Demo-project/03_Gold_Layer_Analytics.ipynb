# %%
import dlt
from pyspark.sql.functions import *

# -----------------------------------------------
# GOLD TABLE 1: Active Customers
# -----------------------------------------------
@dlt.table(
    name = "active_customers",
    comment = "Active customers current snapshot",
    table_properties = {"quality": "gold"}
)
def active_customers():
    return dlt.read("customers").filter(
        (col("__END_AT").isNull()) & (col("account_status") == "ACTIVE")
    ).select(
        "customer_id", "full_name", "email", "city",
        "subscription_plan", "account_status",
        col("__START_AT").alias("valid_from")
    )


# -----------------------------------------------
# GOLD TABLE 2: Plan Metrics
# -----------------------------------------------
@dlt.table(
    name = "plan_metrics",
    comment = "Subscription plan analytics",
    table_properties = {"quality": "gold"}
)
def plan_metrics():
    return dlt.read("customers").filter(col("__END_AT").isNull()).groupBy("subscription_plan").agg(
        count("*").alias("total_customers"),
        sum(when(col("account_status") == "ACTIVE", 1).otherwise(0)).alias("active_customers"),
        sum(when(col("account_status") == "INACTIVE", 1).otherwise(0)).alias("inactive_customers"),
        round(sum(when(col("account_status") == "ACTIVE", 1).otherwise(0)) * 100.0 / count("*"), 2).alias("active_percentage")
    )


# -----------------------------------------------
# GOLD TABLE 3: City Metrics
# -----------------------------------------------
@dlt.table(
    name = "city_metrics",
    comment = "City wise customer distribution",
    table_properties = {"quality": "gold"}
)
def city_metrics():
    return dlt.read("customers").filter(col("__END_AT").isNull()).groupBy("city").agg(
        count("*").alias("total_customers"),
        count(when(col("subscription_plan") == "Gold", 1)).alias("gold_plan_customers"),
        count(when(col("subscription_plan") == "Silver", 1)).alias("silver_plan_customers"),
        count(when(col("subscription_plan") == "Bronze", 1)).alias("bronze_plan_customers"),
        sum(when(col("account_status") == "ACTIVE", 1).otherwise(0)).alias("active_customers")
    )


# -----------------------------------------------
# GOLD TABLE 4: Customer History
# -----------------------------------------------
@dlt.table(
    name = "customer_history",
    comment = "Customers with multiple versions",
    table_properties = {"quality": "gold"}
)
def customer_history():
    return dlt.read("customers").groupBy("customer_id", "full_name").agg(
        count("*").alias("version_count"),
        min("__START_AT").alias("first_seen_date"),
        max("__START_AT").alias("last_updated_date")
    ).filter(col("version_count") > 1)


# -----------------------------------------------
# GOLD TABLE 5: Executive Summary
# -----------------------------------------------
@dlt.table(
    name = "executive_summary",
    comment = "High level KPIs",
    table_properties = {"quality": "gold"}
)
def executive_summary():
    return dlt.read("customers").agg(
        countDistinct("customer_id").alias("total_unique_customers"),
        sum(when(col("__END_AT").isNull(), 1).otherwise(0)).alias("current_customers"),
        sum(when(col("__END_AT").isNull() & (col("account_status") == "ACTIVE"), 1).otherwise(0)).alias("active_customers"),
        sum(when(col("__END_AT").isNull() & (col("account_status") == "INACTIVE"), 1).otherwise(0)).alias("inactive_customers"),
        sum(when(col("__END_AT").isNull() & (col("subscription_plan") == "Gold"), 1).otherwise(0)).alias("gold_subscribers"),
        sum(when(col("__END_AT").isNull() & (col("subscription_plan") == "Silver"), 1).otherwise(0)).alias("silver_subscribers"),
        sum(when(col("__END_AT").isNull() & (col("subscription_plan") == "Bronze"), 1).otherwise(0)).alias("bronze_subscribers"),
        current_date().alias("report_date")
    )
